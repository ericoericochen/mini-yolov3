# %%
# %load_ext autoreload
# %autoreload 2

# %%
from mini_yolov1.dataset import OxfordIIITPetDataset
import matplotlib.pyplot as plt
from mini_yolov1.utils import draw_bounding_boxes
from torchvision.ops import box_convert
from torchvision.transforms import v2

# %%
dataset = OxfordIIITPetDataset(
    root="./data/oxford-iiit-pet/",
    split="trainval",
    transform=v2.Resize((128, 128))
)

# %%
len(dataset)
# Out:
# 3303

# %%
data = dataset[5]
data
# Out:
# {'image': <PIL.Image.Image image mode=RGB size=128x128>,
#  'bbox': tensor([[0.5607, 0.0619, 0.2214, 0.2667]]),
#  'label': tensor([0])}

# %%
data["label"]
# Out:
# tensor([0])

# %%
plt.imshow(draw_bounding_boxes(
    data["image"].resize((256, 256)),
    box_convert(data["bbox"], "xywh", "xyxy"),
    labels=[dataset.LABELS[label] for label in data["label"]]
))

# %%
dataset = OxfordIIITPetDataset(
    root="./data/oxford-iiit-pet/",
    split="test"
)

# %%
len(dataset)
# Out:
# 3303
