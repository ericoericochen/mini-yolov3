# %%
# %load_ext autoreload
# %autoreload 2

# %%
from mini_yolov1.dataset import OxfordIIITPetDataset
import matplotlib.pyplot as plt
from mini_yolov1.utils import draw_bounding_boxes_new
from torchvision.ops import box_convert

# %%
dataset = OxfordIIITPetDataset(
    root="./data/oxford-iiit-pet/",
    split="trainval"
)

# %%
len(dataset)
# Out:
# 3303

# %%
data = dataset[5]
data
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=280x210>,
#  'bbox': tensor([[0.5607, 0.0619, 0.2214, 0.2667]]),
#  'label': tensor([0])}

# %%
data["label"]
# Out:
# tensor([0])

# %%
draw_bounding_boxes_new(
    data["image"],
    box_convert(data["bbox"], "xywh", "xyxy"),
    labels=[dataset.LABELS[label] for label in data["label"]]
)
# Out:
# ['cat']
# <PIL.Image.Image image mode=RGB size=280x210>

# %%
dataset = OxfordIIITPetDataset(
    root="./data/oxford-iiit-pet/",
    split="test"
)

# %%
len(dataset)
# Out:
# 3303
